# %% [markdown]
# <a href="https://colab.research.google.com/github/zkibnksmh/MachineLearningTasks/blob/main/2ndWeekTask/Regression_Data_Public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
# Tentukan path file dataset di Google Drive
path = '/content/drive/MyDrive/Dataset/dummydata.csv'

# Baca dataset menggunakan pandas
df = pd.read_csv(path)

# Tampilkan beberapa baris pertama dari dataset
df.head()
# Out:
#    Age  Income  Number of Children  Years of Education
# 0   30   50000                   2                  12
# 1   45   70000                   1                  16
# 2   35   60000                   3                  14
# 3   50   80000                   2                  18
# 4   25   40000                   0                  10

# %%
#memberikan statistik deskriptif kolom yang ada pada dataset
df.describe()
# Out:
#              Age         Income  Number of Children  Years of Education
# count  45.000000      45.000000           45.000000           45.000000
# mean   45.133333   74355.555556            1.644444           17.177778
# std    12.796661   21195.149054            0.883062            3.779664
# min    24.000000   40000.000000            0.000000           10.000000
# 25%    35.000000   59000.000000            1.000000           15.000000
# 50%    45.000000   70000.000000            2.000000           17.000000
# 75%    55.000000   90000.000000            2.000000           20.000000
# max    70.000000  120000.000000            3.000000           24.000000

# %%
# Membuat plot
sns.lineplot(data=df, x="Age", y="Income")
plt.title('Umur dan Gaji')
plt.xlabel('Umur')
plt.ylabel('Gaji')
plt.show()

# %%
X = df[['Age']]
y = df['Income']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print(f'Koefisien: {model.coef_[0]}')
print(f'Intercept: {model.intercept_}')
print(f'Skor R-squared: {model.score(X, y)}')
# Out:
# Koefisien: 1646.1537038065105
# Intercept: 59.1517237550579
# Skor R-squared: 0.9877821655206647
